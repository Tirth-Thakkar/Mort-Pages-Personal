# %% [markdown]
# ---
# toc: true
# comments: true
# layout: notebook
# author: Tirth Thakkar
# title: Survivorship Lab
# description: Survivorship Lab for APES Data analysis
# categories: [week05, APES]
#
# ---

# %%
import pandas as pd

def analyze_deaths(csv_file, stats_csv_file):
    # Function to calculate age range for a given age
    def calculate_age_range(age):
        return int(age // 5) * 5

    # Load the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Create a new column 'Age Range' to store the age range for each person
    df['Age Range'] = df['Age of Death'].apply(calculate_age_range)

    # Initialize variables to store statistics
    age_range_stats = {}
    total_people = len(df)
    
    # Initialize variables to store cumulative deaths and surviving members
    cumulative_deaths = 0
    
    # Iterate through each unique age range
    for age_range in sorted(df['Age Range'].unique()):
        # Filter the DataFrame for the current age range
        age_range_df = df[df['Age Range'] == age_range]
        
        # Calculate the number of deaths in the current age range
        deaths_in_range = len(age_range_df)
        
        # Update cumulative deaths
        cumulative_deaths += deaths_in_range
        
        # Calculate the number of surviving members in the current age range
        surviving_members = total_people - cumulative_deaths
        
        # Calculate the mortality rate
        mortality_rate = cumulative_deaths / total_people
        
        # Store the statistics in a dictionary
        age_range_stats[age_range] = {
            'Deaths in Range': deaths_in_range,
            'Surviving Members': surviving_members,
            'Mortality Rate': mortality_rate
        }

    # Print the statistics
    for age_range, stats in age_range_stats.items():
        print(f"Age Range {age_range}-{age_range + 4.9} years:")
        print(f"  Number of Deaths: {stats['Deaths in Range']}")
        print(f"  Surviving Members: {stats['Surviving Members']}")
        print(f"  Mortality Rate: {stats['Mortality Rate']:.2%}")
        print()

    # Create a DataFrame for the statistics
    stats_df = pd.DataFrame.from_dict(age_range_stats, orient='index')
    stats_df.index.name = 'Age Range'
    stats_df.reset_index(inplace=True)

    # Save the statistics to a new CSV file
    stats_df.to_csv(stats_csv_file, index=False)

    print(f"Statistics saved to {stats_csv_file}")

if __name__ == '__main__':
    analyze_deaths('/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Data/19th_Cent_NJ_Burials_Women.csv', '/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_women_19th_cent.csv')
    analyze_deaths('/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Data/19th_Cent_NJ_Burials_Men.csv', '/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_men_19th_cent.csv')
    analyze_deaths('/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Data/20th_Cent_SD_Burials_Men.csv', '/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_men_20th_cent.csv')
    analyze_deaths('/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Data/20th_Cent_SD_Burials_Women.csv', '/home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_women_20th_cent.csv')
# Out:
# Age Range 0-4.9 years:
#   Number of Deaths: 8
#   Surviving Members: 142
#   Mortality Rate: 5.33%
#
# Age Range 5-9.9 years:
#   Number of Deaths: 2
#   Surviving Members: 140
#   Mortality Rate: 6.67%
#
# Age Range 10-14.9 years:
#   Number of Deaths: 4
#   Surviving Members: 136
#   Mortality Rate: 9.33%
#
# Age Range 15-19.9 years:
#   Number of Deaths: 2
#   Surviving Members: 134
#   Mortality Rate: 10.67%
#
# Age Range 20-24.9 years:
#   Number of Deaths: 9
#   Surviving Members: 125
#   Mortality Rate: 16.67%
#
# Age Range 25-29.9 years:
#   Number of Deaths: 5
#   Surviving Members: 120
#   Mortality Rate: 20.00%
#
# Age Range 30-34.9 years:
#   Number of Deaths: 7
#   Surviving Members: 113
#   Mortality Rate: 24.67%
#
# Age Range 35-39.9 years:
#   Number of Deaths: 4
#   Surviving Members: 109
#   Mortality Rate: 27.33%
#
# Age Range 40-44.9 years:
#   Number of Deaths: 1
#   Surviving Members: 108
#   Mortality Rate: 28.00%
#
# Age Range 45-49.9 years:
#   Number of Deaths: 8
#   Surviving Members: 100
#   Mortality Rate: 33.33%
#
# Age Range 50-54.9 years:
#   Number of Deaths: 8
#   Surviving Members: 92
#   Mortality Rate: 38.67%
#
# Age Range 55-59.9 years:
#   Number of Deaths: 11
#   Surviving Members: 81
#   Mortality Rate: 46.00%
#
# Age Range 60-64.9 years:
#   Number of Deaths: 3
#   Surviving Members: 78
#   Mortality Rate: 48.00%
#
# Age Range 65-69.9 years:
#   Number of Deaths: 15
#   Surviving Members: 63
#   Mortality Rate: 58.00%
#
# Age Range 70-74.9 years:
#   Number of Deaths: 16
#   Surviving Members: 47
#   Mortality Rate: 68.67%
#
# Age Range 75-79.9 years:
#   Number of Deaths: 17
#   Surviving Members: 30
#   Mortality Rate: 80.00%
#
# Age Range 80-84.9 years:
#   Number of Deaths: 11
#   Surviving Members: 19
#   Mortality Rate: 87.33%
#
# Age Range 85-89.9 years:
#   Number of Deaths: 10
#   Surviving Members: 9
#   Mortality Rate: 94.00%
#
# Age Range 90-94.9 years:
#   Number of Deaths: 8
#   Surviving Members: 1
#   Mortality Rate: 99.33%
#
# Age Range 100-104.9 years:
#   Number of Deaths: 1
#   Surviving Members: 0
#   Mortality Rate: 100.00%
#
# Statistics saved to /home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_women_19th_cent.csv
# Age Range 0-4.9 years:
#   Number of Deaths: 8
#   Surviving Members: 142
#   Mortality Rate: 5.33%
#
# Age Range 5-9.9 years:
#   Number of Deaths: 2
#   Surviving Members: 140
#   Mortality Rate: 6.67%
#
# Age Range 10-14.9 years:
#   Number of Deaths: 2
#   Surviving Members: 138
#   Mortality Rate: 8.00%
#
# Age Range 15-19.9 years:
#   Number of Deaths: 3
#   Surviving Members: 135
#   Mortality Rate: 10.00%
#
# Age Range 20-24.9 years:
#   Number of Deaths: 2
#   Surviving Members: 133
#   Mortality Rate: 11.33%
#
# Age Range 25-29.9 years:
#   Number of Deaths: 2
#   Surviving Members: 131
#   Mortality Rate: 12.67%
#
# Age Range 30-34.9 years:
#   Number of Deaths: 4
#   Surviving Members: 127
#   Mortality Rate: 15.33%
#
# Age Range 35-39.9 years:
#   Number of Deaths: 4
#   Surviving Members: 123
#   Mortality Rate: 18.00%
#
# Age Range 40-44.9 years:
#   Number of Deaths: 2
#   Surviving Members: 121
#   Mortality Rate: 19.33%
#
# Age Range 45-49.9 years:
#   Number of Deaths: 2
#   Surviving Members: 119
#   Mortality Rate: 20.67%
#
# Age Range 50-54.9 years:
#   Number of Deaths: 9
#   Surviving Members: 110
#   Mortality Rate: 26.67%
#
# Age Range 55-59.9 years:
#   Number of Deaths: 8
#   Surviving Members: 102
#   Mortality Rate: 32.00%
#
# Age Range 60-64.9 years:
#   Number of Deaths: 15
#   Surviving Members: 87
#   Mortality Rate: 42.00%
#
# Age Range 65-69.9 years:
#   Number of Deaths: 13
#   Surviving Members: 74
#   Mortality Rate: 50.67%
#
# Age Range 70-74.9 years:
#   Number of Deaths: 20
#   Surviving Members: 54
#   Mortality Rate: 64.00%
#
# Age Range 75-79.9 years:
#   Number of Deaths: 15
#   Surviving Members: 39
#   Mortality Rate: 74.00%
#
# Age Range 80-84.9 years:
#   Number of Deaths: 17
#   Surviving Members: 22
#   Mortality Rate: 85.33%
#
# Age Range 85-89.9 years:
#   Number of Deaths: 15
#   Surviving Members: 7
#   Mortality Rate: 95.33%
#
# Age Range 90-94.9 years:
#   Number of Deaths: 4
#   Surviving Members: 3
#   Mortality Rate: 98.00%
#
# Age Range 95-99.9 years:
#   Number of Deaths: 2
#   Surviving Members: 1
#   Mortality Rate: 99.33%
#
# Age Range 100-104.9 years:
#   Number of Deaths: 1
#   Surviving Members: 0
#   Mortality Rate: 100.00%
#
# Statistics saved to /home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_men_19th_cent.csv
# Age Range 0-4.9 years:
#   Number of Deaths: 12
#   Surviving Members: 151
#   Mortality Rate: 7.36%
#
# Age Range 5-9.9 years:
#   Number of Deaths: 1
#   Surviving Members: 150
#   Mortality Rate: 7.98%
#
# Age Range 10-14.9 years:
#   Number of Deaths: 1
#   Surviving Members: 149
#   Mortality Rate: 8.59%
#
# Age Range 15-19.9 years:
#   Number of Deaths: 1
#   Surviving Members: 148
#   Mortality Rate: 9.20%
#
# Age Range 20-24.9 years:
#   Number of Deaths: 4
#   Surviving Members: 144
#   Mortality Rate: 11.66%
#
# Age Range 25-29.9 years:
#   Number of Deaths: 1
#   Surviving Members: 143
#   Mortality Rate: 12.27%
#
# Age Range 30-34.9 years:
#   Number of Deaths: 5
#   Surviving Members: 138
#   Mortality Rate: 15.34%
#
# Age Range 35-39.9 years:
#   Number of Deaths: 6
#   Surviving Members: 132
#   Mortality Rate: 19.02%
#
# Age Range 40-44.9 years:
#   Number of Deaths: 2
#   Surviving Members: 130
#   Mortality Rate: 20.25%
#
# Age Range 45-49.9 years:
#   Number of Deaths: 4
#   Surviving Members: 126
#   Mortality Rate: 22.70%
#
# Age Range 50-54.9 years:
#   Number of Deaths: 6
#   Surviving Members: 120
#   Mortality Rate: 26.38%
#
# Age Range 55-59.9 years:
#   Number of Deaths: 7
#   Surviving Members: 113
#   Mortality Rate: 30.67%
#
# Age Range 60-64.9 years:
#   Number of Deaths: 14
#   Surviving Members: 99
#   Mortality Rate: 39.26%
#
# Age Range 65-69.9 years:
#   Number of Deaths: 14
#   Surviving Members: 85
#   Mortality Rate: 47.85%
#
# Age Range 70-74.9 years:
#   Number of Deaths: 28
#   Surviving Members: 57
#   Mortality Rate: 65.03%
#
# Age Range 75-79.9 years:
#   Number of Deaths: 19
#   Surviving Members: 38
#   Mortality Rate: 76.69%
#
# Age Range 80-84.9 years:
#   Number of Deaths: 23
#   Surviving Members: 15
#   Mortality Rate: 90.80%
#
# Age Range 85-89.9 years:
#   Number of Deaths: 9
#   Surviving Members: 6
#   Mortality Rate: 96.32%
#
# Age Range 90-94.9 years:
#   Number of Deaths: 4
#   Surviving Members: 2
#   Mortality Rate: 98.77%
#
# Age Range 95-99.9 years:
#   Number of Deaths: 2
#   Surviving Members: 0
#   Mortality Rate: 100.00%
#
# Statistics saved to /home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_men_20th_cent.csv
# Age Range 0-4.9 years:
#   Number of Deaths: 8
#   Surviving Members: 129
#   Mortality Rate: 5.84%
#
# Age Range 5-9.9 years:
#   Number of Deaths: 1
#   Surviving Members: 128
#   Mortality Rate: 6.57%
#
# Age Range 10-14.9 years:
#   Number of Deaths: 1
#   Surviving Members: 127
#   Mortality Rate: 7.30%
#
# Age Range 15-19.9 years:
#   Number of Deaths: 3
#   Surviving Members: 124
#   Mortality Rate: 9.49%
#
# Age Range 20-24.9 years:
#   Number of Deaths: 2
#   Surviving Members: 122
#   Mortality Rate: 10.95%
#
# Age Range 25-29.9 years:
#   Number of Deaths: 1
#   Surviving Members: 121
#   Mortality Rate: 11.68%
#
# Age Range 30-34.9 years:
#   Number of Deaths: 2
#   Surviving Members: 119
#   Mortality Rate: 13.14%
#
# Age Range 35-39.9 years:
#   Number of Deaths: 3
#   Surviving Members: 116
#   Mortality Rate: 15.33%
#
# Age Range 40-44.9 years:
#   Number of Deaths: 6
#   Surviving Members: 110
#   Mortality Rate: 19.71%
#
# Age Range 45-49.9 years:
#   Number of Deaths: 3
#   Surviving Members: 107
#   Mortality Rate: 21.90%
#
# Age Range 50-54.9 years:
#   Number of Deaths: 3
#   Surviving Members: 104
#   Mortality Rate: 24.09%
#
# Age Range 55-59.9 years:
#   Number of Deaths: 5
#   Surviving Members: 99
#   Mortality Rate: 27.74%
#
# Age Range 60-64.9 years:
#   Number of Deaths: 9
#   Surviving Members: 90
#   Mortality Rate: 34.31%
#
# Age Range 65-69.9 years:
#   Number of Deaths: 12
#   Surviving Members: 78
#   Mortality Rate: 43.07%
#
# Age Range 70-74.9 years:
#   Number of Deaths: 12
#   Surviving Members: 66
#   Mortality Rate: 51.82%
#
# Age Range 75-79.9 years:
#   Number of Deaths: 16
#   Surviving Members: 50
#   Mortality Rate: 63.50%
#
# Age Range 80-84.9 years:
#   Number of Deaths: 17
#   Surviving Members: 33
#   Mortality Rate: 75.91%
#
# Age Range 85-89.9 years:
#   Number of Deaths: 17
#   Surviving Members: 16
#   Mortality Rate: 88.32%
#
# Age Range 90-94.9 years:
#   Number of Deaths: 14
#   Surviving Members: 2
#   Mortality Rate: 98.54%
#
# Age Range 95-99.9 years:
#   Number of Deaths: 1
#   Surviving Members: 1
#   Mortality Rate: 99.27%
#
# Age Range 100-104.9 years:
#   Number of Deaths: 1
#   Surviving Members: 0
#   Mortality Rate: 100.00%
#
# Statistics saved to /home/tirth/vscode/Mort-Pages-Personal/_data/CSV_Output/age_range_statistics_women_20th_cent.csv
